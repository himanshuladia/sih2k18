# %%
import geopandas as gpd

# %%
gpd.read_file('Kurudu_Drainage.shp')
# Out:
#                        PI_CODE            category dr_code     layer  \
# 0                                           Stream    DRST  Drainage
# 1                                           Stream    DRST  Drainage
# 2                                           Stream    DRST  Drainage
# 3                                           Stream    DRST  Drainage
# 4                                           Stream    DRST  Drainage
# 5                                           Stream    DRST  Drainage
# 6                                           Stream    DRST  Drainage
# 7                                           Stream    DRST  Drainage
# 8                                           Stream    DRST  Drainage
# 9                                           Stream    DRST  Drainage
# 10                                          Stream    DRST  Drainage
# 11                                          Stream    DRST  Drainage
# 12                                          Stream    DRST  Drainage
# ...

# %%
df = gpd.read_file('Kurudu_LULC.shp')
df[df['dscr1'] == 'Agricultural land']
# Out:
#    lc_code              dscr1                   dscr2                   dscr3  \
# 27    AGPL  Agricultural land  Agriculture plantation  Agriculture plantation
# 28    AGPL  Agricultural land  Agriculture plantation  Agriculture plantation
# 29    AGPL  Agricultural land  Agriculture plantation  Agriculture plantation
# 30    AGPL  Agricultural land  Agriculture plantation  Agriculture plantation
# 31    AGPL  Agricultural land  Agriculture plantation  Agriculture plantation
# 32    AGPL  Agricultural land  Agriculture plantation  Agriculture plantation
# 33    AGPL  Agricultural land  Agriculture plantation  Agriculture plantation
# 34    AGCR  Agricultural land               Crop land               Crop land
# 35    AGCR  Agricultural land               Crop land               Crop land
# 36    AGCR  Agricultural land               Crop land               Crop land
# 37    AGCR  Agricultural land               Crop land               Crop land
#
# ...
